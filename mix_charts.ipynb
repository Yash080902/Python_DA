# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from urllib.request import urlretrieve

# %%
from urllib.request import urlretrieve, Request, urlopen

# Define the URL and the filename
url = 'https://cdn-0.emojis.wiki/emoji-pics/facebook/bar-chart-facebook.png'
filename = 'chart.jpg'

# Set up a request with a User-Agent header
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})

# Open the URL and save the file
with urlopen(req) as response, open(filename, 'wb') as out_file:
    out_file.write(response.read())

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 8))
axes[0,0].plot(years,oranges, 'o-r')
axes[0,0].plot(years, apples, 'x-y')
